# %%
#Create bar plot of average ratings of all vs average rating of fire 
#sentiment analysis of description 
# brands with most products 
#

# %%
import pandas as pd 

pd.read_json("data.json")
# Out:
#                                                   title      brand  \
# 0     Lenovo Tab M8 Tablet, 8" HD Android Tablet, Qu...     Lenovo
# 1     Android Tablet 10 Inch, 5G WiFi Tablet, 16 GB ...      Hoozo
# 2     Kids Tablet 7 Android Kids Tablet Toddler Tabl...  TOPELOTEK
# 3     Dragon Touch Notepad K10 Tablet, 10 inch Andro...     Dragon
# 4     Dragon Touch K10 Tablet, 10 inch Android Table...     Dragon
# ...                                                 ...        ...
# 9581  Pritom 7 inch Kids Tablet | Quad Core Android,...     PRITOM
# 9582           Fire 7 tablet (7" display, 16 GB) - Sage     Amazon
# 9583  Tablets 10.1 inch 2 in 1 Android 9.0 Tablet wi...      GOWIN
# 9584  SAMSUNG SM-T510NZDFXAR Galaxy Tab A 10.1 64 GB...    Samsung
# 9585  SAMSUNG SM-T290NZSAXAR, Galaxy Tab A 8.0" 32 G...    Samsung
#
#                   rating      num_reviews    price  \
# 0     4.5 out of 5 stars      514 ratings   $89.99
# 1     3.9 out of 5 stars    2,101 ratings   $91.77
# ...

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
plt.style.use('ggplot')

df = pd.read_csv("data.csv")
summarised_results = df["rating"].value_counts()
plt.bar(summarised_results.keys(), summarised_results.values)
plt.show()

# %%
rating_df = df['rating'].value_counts()

rating_df
# Out:
# 5.0 out of 5 stars    246
# 4.0 out of 5 stars    169
# 4.5 out of 5 stars    123
# 3.5 out of 5 stars    118
# 4.1 out of 5 stars    113
# 3.8 out of 5 stars    111
# 4.2 out of 5 stars    109
# 3.7 out of 5 stars    107
# 3.9 out of 5 stars    106
# 4.4 out of 5 stars    105
# 4.6 out of 5 stars     96
# 4.3 out of 5 stars     96
# 3.6 out of 5 stars     90
# 4.7 out of 5 stars     84
# 3.0 out of 5 stars     83
# 3.3 out of 5 stars     68
# 3.4 out of 5 stars     65
# 3.2 out of 5 stars     59
# 1.0 out of 5 stars     57
# 3.1 out of 5 stars     57
# 4.8 out of 5 stars     38
# 2.0 out of 5 stars     31
# 2.9 out of 5 stars     26
# 2.6 out of 5 stars     23
# 2.8 out of 5 stars     21
# 2.5 out of 5 stars     17
# 2.7 out of 5 stars     15
# 4.9 out of 5 stars      8
# 2.3 out of 5 stars      8
# 1.9 out of 5 stars      7
# 2.4 out of 5 stars      7
# 2.2 out of 5 stars      5
# 1.7 out of 5 stars      3
# 1.6 out of 5 stars      3
# 1.4 out of 5 stars      3
# ...

# %%
df['first'] = df['rating'].str.split('.').str[0]

first_df = df['first'].value_counts()
first_df
# Out:
# 4    941
# 3    864
# 5    246
# 2    156
# 1     76
# Name: first, dtype: int64

# %%
# df['count'] = df['rating'].str.split('out').str[0]

# rating_df = df['count'].value_counts()

# df2= pd.DataFrame(rating_df)
# df2
# Out:
#       count
# 5.0     246
# 4.0     169
# 4.5     123
# 3.5     118
# 4.1     113
# 3.8     111
# 4.2     109
# 3.7     107
# 3.9     106
# 4.4     105
# 4.6      96
# 4.3      96
# 3.6      90
# 4.7      84
# 3.0      83
# 3.3      68
# 3.4      65
# 3.2      59
# 3.1      57
# 1.0      57
# 4.8      38
# 2.0      31
# 2.9      26
# 2.6      23
# 2.8      21
# 2.5      17
# 2.7      15
# 2.3       8
# 4.9       8
# 2.4       7
# 1.9       7
# 2.2       5
# 2.1       3
# 1.6       3
# 1.7       3
# 1.4       3
# 1.8       1
# 1.3       1
# 1.5       1

# %%
plt.style.use('ggplot')

summarised_results = first_df
plt.bar(summarised_results.keys(), summarised_results.values)
plt.show()

# %%
ax1 = plt.subplots()
ax1.hist(rating_df, 5)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-98e79e6f1289> in <module>
#       1 ax1 = plt.subplots()
# ----> 2 ax1.hist(rating_df, 5)
#       3 plt.tight_layout()
#       4 plt.show()
#
# AttributeError: 'tuple' object has no attribute 'hist'

# %%
df[df['title'].str.contains("Fire")]

#Search title for Fire
# Out:
#        brand                                        description  \
# 4     Amazon  A Certified Refurbished Fire 7 Tablet is refur...
# 13    Amazon  Save up to $99 on a full-featured Fire HD 10 t...
# 15    Amazon  Save up to $94.98 on a full-featured Fire HD 8...
# 22    Amazon  A Certified Refurbished Fire HD 10 Tablet is r...
# 27    Amazon  Contains two Fire 7 Kids Edition tablets (16 G...
# ...      ...                                                ...
# 9544  Amazon  A Certified Refurbished Fire HD 10 Tablet is r...
# 9566  Amazon  8" HD display, 2X the storage (32 or 64 GB of ...
# 9573  Amazon  8" HD display, 2X the storage (32 or 64 GB of ...
# 9574  Amazon  10.1" 1080p full HD display; 32 or 64 GB of in...
# 9575  Amazon  7" IPS display; 16 or 32 GB of internal storag...
#
#           num_reviews    price              rating  \
# 4       2,140 ratings   $59.99  4.4 out of 5 stars
# 13     12,609 ratings  $199.99  4.7 out of 5 stars
# ...
